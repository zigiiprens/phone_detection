# %%
# Phone Detector by classification with pretrained model in keras
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
# import MobilenetV2
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

model = MobileNetV2(weights='imagenet')

# %%
#Test with an image "phones.jpg"

img_path = 'data/phones.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n07615774', 'ice_lolly', 0.35492143), ('n03944341', 'pinwheel', 0.0695467), ('n07718472', 'cucumber', 0.048650816)]

# %%
#Test with an image "phones1.jpg"

img_path = 'data/phones1.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03584254', 'iPod', 0.8832403), ('n02992529', 'cellular_telephone', 0.072092816), ('n03485407', 'hand-held_computer', 0.0057778987)]

# %%
#Test with an image "phones2.jpg"

img_path = 'data/phones2.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03485407', 'hand-held_computer', 0.5177215), ('n02992529', 'cellular_telephone', 0.32615966), ('n03584254', 'iPod', 0.09369465)]

# %%
#Test with an image "phones3.jpg"

img_path = 'data/phones3.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03902125', 'pay-phone', 0.35243043), ('n04404412', 'television', 0.042138662), ('n04591157', 'Windsor_tie', 0.04179316)]

# %%
#Test with an image "phones4.jpg"

img_path = 'data/phones4.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02992529', 'cellular_telephone', 0.5744221), ('n03584254', 'iPod', 0.15267295), ('n03485407', 'hand-held_computer', 0.098524)]

# %%
########################################################
########################################################
########################################################

# %%
# import MobileNet
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input, decode_predictions

model = MobileNet(weights='imagenet')

# %%
#Test with an image "phones.jpg"

img_path = 'data/phones.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02883205', 'bow_tie', 0.21185458), ('n03920288', 'Petri_dish', 0.06904627), ('n02951585', 'can_opener', 0.05599317)]

# %%
#Test with an image "phones1.jpg"

img_path = 'data/phones1.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03584254', 'iPod', 0.9314711), ('n02992529', 'cellular_telephone', 0.05744154), ('n04074963', 'remote_control', 0.0056878626)]

# %%
#Test with an image "phones2.jpg"

img_path = 'data/phones2.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03485407', 'hand-held_computer', 0.6230725), ('n02992529', 'cellular_telephone', 0.2973305), ('n03777754', 'modem', 0.052336056)]

# %%
#Test with an image "phones3.jpg"

img_path = 'data/phones3.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03770439', 'miniskirt', 0.2752121), ('n02910353', 'buckle', 0.17803548), ('n03709823', 'mailbag', 0.0743755)]

# %%
#Test with an image "phones4.jpg"

img_path = 'data/phones4.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])

# %%
########################################################
########################################################
########################################################

# %%
# import InceptionResNetV2
from tensorflow.keras.applications.inception_resnet_v2 import InceptionResNetV2, preprocess_input, decode_predictions

model = InceptionResNetV2(weights='imagenet')

# %%
#Test with an image "phones.jpg"

img_path = 'data/phones.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03041632', 'cleaver', 0.4395587), ('n02992529', 'cellular_telephone', 0.1413797), ('n04074963', 'remote_control', 0.10484776)]

# %%
#Test with an image "phones1.jpg"

img_path = 'data/phones1.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03584254', 'iPod', 0.8351591), ('n02992529', 'cellular_telephone', 0.05909214), ('n03485407', 'hand-held_computer', 0.014326364)]

# %%
#Test with an image "phones2.jpg"

img_path = 'data/phones2.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02992529', 'cellular_telephone', 0.50255734), ('n03485407', 'hand-held_computer', 0.3365247), ('n03584254', 'iPod', 0.034867495)]

# %%
#Test with an image "phones3.jpg"

img_path = 'data/phones3.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02910353', 'buckle', 0.703434), ('n03832673', 'notebook', 0.03325023), ('n03642806', 'laptop', 0.028080486)]

# %%
#Test with an image "phones4.jpg"

img_path = 'data/phones4.jpg'
# img = Image.open(img_path)
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
# x = Image.fromarray(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n02992529', 'cellular_telephone', 0.7954354), ('n03584254', 'iPod', 0.008711099), ('n04069434', 'reflex_camera', 0.0082703745)]

# %%
########################################################
########################################################
########################################################
